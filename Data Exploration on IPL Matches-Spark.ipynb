# %% [markdown]
# # Data Exploration using Spark Dataframes and SQL

# %% [markdown]
# ## Setting up Spark and other dependencies

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/Datasets
# Out:
# /content/drive/MyDrive/Colab Notebooks/Datasets

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Datasets'

# %%
#!wget -q https://archive.apache.org/dist/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz
#!tar xf spark-3.0.1-bin-hadoop2.7.tgz
#!apt-get install openjdk-8-jdk-headless -qq > /dev/null
#os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
#os.environ["SPARK_HOME"] = "/content/drive/MyDrive/Colab Notebooks/Datasets/spark-3.0.1-bin-hadoop2.7"
#import findspark
#findspark.init()

#import pyspark

# %%
# !pip install -q findspark

# %%
# !pip install -q pyspark
# Out:
#   Building wheel for pyspark (setup.py) ... done

# %%
import os
import sys

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Spark RDD').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ca5d5120e53c:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark RDD</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Reading File

# %%
import pandas as pd
import numpy as np

# %%
sc = spark.sparkContext

# %%
fileRDD = sc.textFile('/content/drive/MyDrive/Colab Notebooks/Datasets/matches_test.csv')

# %% [markdown]
# ## Setting up schema

# %%
print(f'Number of records in file: {fileRDD.count()}')
# Out:
# Number of records in file: 748

# %%
#displaying the first 5 lines
print(fileRDD.take(100))
# Out:
# ['Season,city,date,team1,team2,toss_winner,toss_decision,result,dl_applied,winner,win_by_runs,win_by_wickets,player_of_match', 'IPL-2017,Hyderabad,05/04/17,Sunrisers Hyderabad,Royal Challengers Bangalore,Royal Challengers Bangalore,field,normal,0,Sunrisers Hyderabad,35,0,Yuvraj Singh', 'IPL-2017,Pune,06/04/17,Mumbai Indians,Rising Pune Supergiant,Rising Pune Supergiant,field,normal,0,Rising Pune Supergiant,0,7,SPD Smith', 'IPL-2017,Rajkot,07/04/17,Gujarat Lions,Kolkata Knight Riders,Kolkata Knight Riders,field,normal,0,Kolkata Knight Riders,0,10,CA Lynn', 'IPL-2017,Indore,08/04/17,Rising Pune Supergiant,Kings XI Punjab,Kings XI Punjab,field,normal,0,Kings XI Punjab,0,6,GJ Maxwell', 'IPL-2017,Bangalore,08/04/17,Royal Challengers Bangalore,Delhi Daredevils,Royal Challengers Bangalore,bat,normal,0,Royal Challengers Bangalore,15,0,KM Jadhav', 'IPL-2017,Hyderabad,09/04/17,Gujarat Lions,Sunrisers Hyderabad,Sunrisers Hyderabad,field,normal,0,Sunrisers Hyderabad,0,9,Rashid Khan', 'IPL-2017,Mumbai,09/04/17,Kolkata Knight Riders,Mumbai Indians,Mumbai Indians,field,normal,0,Mumbai Indians,0,4,N Rana', 'IPL-2017,Indore,10/04/17,Royal Challengers Bangalore,Kings XI Punjab,Royal Challengers Bangalore,bat,normal,0,Kings XI Punjab,0,8,AR Patel', 'IPL-2017,Pune,11/04/17,Delhi Daredevils,Rising Pune Supergiant,Rising Pune Supergiant,field,normal,0,Delhi Daredevils,97,0,SV Samson', 'IPL-2017,Mumbai,12/04/17,Sunrisers Hyderabad,Mumbai Indians,Mumbai Indians,field,normal,0,Mumbai Indians,0,4,JJ Bumrah', 'IPL-2017,Kolkata,13/04/17,Kings XI Punjab,Kolkata Knight Riders,Kolkata Knight Riders,field,normal,0,Kolkata Knight Riders,0,8,SP Narine', 'IPL-2017,Bangalore,14/04/17,Royal Challengers Bangalore,Mumbai Indians,Mumbai Indians,field,normal,0,Mumbai Indians,0,4,KA Pollard', 'IPL-2017,Rajkot,14/04/17,Rising Pune Supergiant,Gujarat Lions,Gujarat Lions,field,normal,0,Gujarat Lions,0,7,AJ Tye', 'IPL-2017,Kolkata,15/04/17,Kolkata Knight Riders,Sunrisers Hyderabad,Sunrisers Hyderabad,field,normal,0,Kolkata Knight Riders,17,0,RV Uthappa', 'IPL-2017,Delhi,15/04/17,Delhi Daredevils,Kings XI Punjab,Delhi Daredevils,bat,normal,0,Delhi Daredevils,51,0,CJ Anderson', 'IPL-2017,Mumbai,16/04/17,Gujarat Lions,Mumbai Indians,Mumbai Indians,field,normal,0,Mumbai Indians,0,6,N Rana', 'IPL-2017,Bangalore,16/04/17,Rising Pune Supergiant,Royal Challengers Bangalore,Royal Challengers Bangalore,field,normal,0,Rising Pune Supergiant,27,0,BA Stokes', 'IPL-2017,Delhi,17/04/17,Delhi Daredevils,Kolkata Knight Riders,Delhi Daredevils,bat,normal,0,Kolkata Knight Riders,0,4,NM Coulter-Nile', 'IPL-2017,Hyderabad,17/04/17,Sunrisers Hyderabad,Kings XI Punjab,Kings XI Punjab,field,normal,0,Sunrisers Hyderabad,5,0,B Kumar', 'IPL-2017,Rajkot,18/04/17,Royal Challengers Bangalore,Gujarat Lions,Gujarat Lions,field,normal,0,Royal Challengers Bangalore,21,0,CH Gayle', 'IPL-2017,Hyderabad,19/04/17,Sunrisers Hyderabad,Delhi Daredevils,Sunrisers Hyderabad,bat,normal,0,Sunrisers Hyderabad,15,0,KS Williamson', 'IPL-2017,Indore,20/04/17,Kings XI Punjab,Mumbai Indians,Mumbai Indians,field,normal,0,Mumbai Indians,0,8,JC Buttler', 'IPL-2017,Kolkata,21/04/17,Kolkata Knight Riders,Gujarat Lions,Gujarat Lions,field,normal,0,Gujarat Lions,0,4,SK Raina', 'IPL-2017,Mumbai,22/04/17,Mumbai Indians,Delhi Daredevils,Delhi Daredevils,field,normal,0,Mumbai Indians,14,0,MJ McClenaghan', 'IPL-2017,Pune,22/04/17,Sunrisers Hyderabad,Rising Pune Supergiant,Rising Pune Supergiant,field,normal,0,Rising Pune Supergiant,0,6,MS Dhoni', 'IPL-2017,Rajkot,23/04/17,Kings XI Punjab,Gujarat Lions,Gujarat Lions,field,normal,0,Kings XI Punjab,26,0,HM Amla', 'IPL-2017,Kolkata,23/04/17,Kolkata Knight Riders,Royal Challengers Bangalore,Royal Challengers Bangalore,field,normal,0,Kolkata Knight Riders,82,0,NM Coulter-Nile', 'IPL-2017,Mumbai,24/04/17,Rising Pune Supergiant,Mumbai Indians,Mumbai Indians,field,normal,0,Rising Pune Supergiant,3,0,BA Stokes', 'IPL-2017,Pune,26/04/17,Rising Pune Supergiant,Kolkata Knight Riders,Kolkata Knigh ...

# %%
#Removing the header
header = fileRDD.first()
fileRDD = fileRDD.filter(lambda line: line != header)
print(f'Count after removal of header: {fileRDD.count()}')
print('Displaying first 5 records after header removal \n')
print(fileRDD.take(5))
# Out:
# Count after removal of header: 747
# Displaying first 5 records after header removal
#
# ['IPL-2017,Hyderabad,05/04/17,Sunrisers Hyderabad,Royal Challengers Bangalore,Royal Challengers Bangalore,field,normal,0,Sunrisers Hyderabad,35,0,Yuvraj Singh', 'IPL-2017,Pune,06/04/17,Mumbai Indians,Rising Pune Supergiant,Rising Pune Supergiant,field,normal,0,Rising Pune Supergiant,0,7,SPD Smith', 'IPL-2017,Rajkot,07/04/17,Gujarat Lions,Kolkata Knight Riders,Kolkata Knight Riders,field,normal,0,Kolkata Knight Riders,0,10,CA Lynn', 'IPL-2017,Indore,08/04/17,Rising Pune Supergiant,Kings XI Punjab,Kings XI Punjab,field,normal,0,Kings XI Punjab,0,6,GJ Maxwell', 'IPL-2017,Bangalore,08/04/17,Royal Challengers Bangalore,Delhi Daredevils,Royal Challengers Bangalore,bat,normal,0,Royal Challengers Bangalore,15,0,KM Jadhav']

# %%
header
# Out:
# 'Season,city,date,team1,team2,toss_winner,toss_decision,result,dl_applied,winner,win_by_runs,win_by_wickets,player_of_match'

# %%
# Split the data into individual columns
fileRDD = fileRDD.map(lambda line: line.split(','))
print('Data after splitting \n')
print(fileRDD.take(5))
# Out:
# Data after splitting
#
# [['IPL-2017', 'Hyderabad', '05/04/17', 'Sunrisers Hyderabad', 'Royal Challengers Bangalore', 'Royal Challengers Bangalore', 'field', 'normal', '0', 'Sunrisers Hyderabad', '35', '0', 'Yuvraj Singh'], ['IPL-2017', 'Pune', '06/04/17', 'Mumbai Indians', 'Rising Pune Supergiant', 'Rising Pune Supergiant', 'field', 'normal', '0', 'Rising Pune Supergiant', '0', '7', 'SPD Smith'], ['IPL-2017', 'Rajkot', '07/04/17', 'Gujarat Lions', 'Kolkata Knight Riders', 'Kolkata Knight Riders', 'field', 'normal', '0', 'Kolkata Knight Riders', '0', '10', 'CA Lynn'], ['IPL-2017', 'Indore', '08/04/17', 'Rising Pune Supergiant', 'Kings XI Punjab', 'Kings XI Punjab', 'field', 'normal', '0', 'Kings XI Punjab', '0', '6', 'GJ Maxwell'], ['IPL-2017', 'Bangalore', '08/04/17', 'Royal Challengers Bangalore', 'Delhi Daredevils', 'Royal Challengers Bangalore', 'bat', 'normal', '0', 'Royal Challengers Bangalore', '15', '0', 'KM Jadhav']]

# %%
Schema = StructType([
    #StructField("id", StringType(), True)
    StructField("Season", StringType(), True),
    StructField("city", StringType(), True),
    StructField("date", StringType(), True),
    StructField("team1", StringType(), True),
    StructField("team2", StringType(), True),
    StructField("toss_winner", StringType(), True),
    StructField("toss_decision", StringType(), True),
    StructField("result", StringType(), True),
    StructField("dl_applied", StringType(), True),
    StructField("winner", StringType(), True),
    StructField("win_by_runs", StringType(), True),
    StructField("win_by_wickets", StringType(), True),
    StructField("player_of_match", StringType(), True)
])

# %%
matches = spark.createDataFrame(data = fileRDD, schema= Schema)

# %%
matches.show(5, truncate= False)
# Out:
# +--------+---------+--------+---------------------------+---------------------------+---------------------------+-------------+------+----------+---------------------------+-----------+--------------+---------------+
# |Season  |city     |date    |team1                      |team2                      |toss_winner                |toss_decision|result|dl_applied|winner                     |win_by_runs|win_by_wickets|player_of_match|
# +--------+---------+--------+---------------------------+---------------------------+---------------------------+-------------+------+----------+---------------------------+-----------+--------------+---------------+
# |IPL-2017|Hyderabad|05/04/17|Sunrisers Hyderabad        |Royal Challengers Bangalore|Royal Challengers Bangalore|field        |normal|0         |Sunrisers Hyderabad        |35         |0             |Yuvraj Singh   |
# |IPL-2017|Pune     |06/04/17|Mumbai Indians             |Rising Pune Supergiant     |Rising Pune Supergiant     |field        |normal|0         |Rising Pune Supergiant     |0          |7             |SPD Smith      |
# |IPL-2017|Rajkot   |07/04/17|Gujarat Lions              |Kolkata Knight Riders      |Kolkata Knight Riders      |field        |normal|0         |Kolkata Knight Riders      |0          |10            |CA Lynn        |
# |IPL-2017|Indore   |08/04/17|Rising Pune Supergiant     |Kings XI Punjab            |Kings XI Punjab            |field        |normal|0         |Kings XI Punjab            |0          |6             |GJ Maxwell     |
# |IPL-2017|Bangalore|08/04/17|Royal Challengers Bangalore|Delhi Daredevils           |Royal Challengers Bangalore|bat          |normal|0         |Royal Challengers Bangalore|15         |0             |KM Jadhav      |
# +--------+---------+--------+---------------------------+---------------------------+---------------------------+-------------+------+----------+---------------------------+-----------+--------------+---------------+
# only showing top 5 rows

# %%
matches.createOrReplaceTempView('matchesTable')

# %%
spark.sql('select * from matchesTable').show()
# Out:
# +--------+---------+--------+--------------------+--------------------+--------------------+-------------+------+----------+--------------------+-----------+--------------+---------------+
# |  Season|     city|    date|               team1|               team2|         toss_winner|toss_decision|result|dl_applied|              winner|win_by_runs|win_by_wickets|player_of_match|
# +--------+---------+--------+--------------------+--------------------+--------------------+-------------+------+----------+--------------------+-----------+--------------+---------------+
# |IPL-2017|Hyderabad|05/04/17| Sunrisers Hyderabad|Royal Challengers...|Royal Challengers...|        field|normal|         0| Sunrisers Hyderabad|         35|             0|   Yuvraj Singh|
# |IPL-2017|     Pune|06/04/17|      Mumbai Indians|Rising Pune Super...|Rising Pune Super...|        field|normal|         0|Rising Pune Super...|          0|             7|      SPD Smith|
# |IPL-2017|   Rajkot|07/04/17|       Gujarat Lions|Kolkata Knight Ri...|Kolkata Knight Ri...|        field|normal|         0|Kolkata Knight Ri...|          0|            10|        CA Lynn|
# |IPL-2017|   Indore|08/04/17|Rising Pune Super...|     Kings XI Punjab|     Kings XI Punjab|        field|normal|         0|     Kings XI Punjab|          0|             6|     GJ Maxwell|
# |IPL-2017|Bangalore|08/04/17|Royal Challengers...|    Delhi Daredevils|Royal Challengers...|          bat|normal|         0|Royal Challengers...|         15|             0|      KM Jadhav|
# |IPL-2017|Hyderabad|09/04/17|       Gujarat Lions| Sunrisers Hyderabad| Sunrisers Hyderabad|        field|normal|         0| Sunrisers Hyderabad|          0|             9|    Rashid Khan|
# |IPL-2017|   Mumbai|09/04/17|Kolkata Knight Ri...|      Mumbai Indians|      Mumbai Indians|        field|normal|         0|      Mumbai Indians|          0|             4|         N Rana|
# |IPL-2017|   Indore|10/04/17|Royal Challengers...|     Kings XI Punjab|Royal Challengers...|          bat|normal|         0|     Kings XI Punjab|          0|             8|       AR Patel|
# |IPL-2017|     Pune|11/04/17|    Delhi Daredevils|Rising Pune Super...|Rising Pune Super...|        field|normal|         0|    Delhi Daredevils|         97|             0|      SV Samson|
# |IPL-2017|   Mumbai|12/04/17| Sunrisers Hyderabad|      Mumbai Indians|      Mumbai Indians|        field|normal|         0|      Mumbai Indians|          0|             4|      JJ Bumrah|
# |IPL-2017|  Kolkata|13/04/17|     Kings XI Punjab|Kolkata Knight Ri...|Kolkata Knight Ri...|        field|normal|         0|Kolkata Knight Ri...|          0|             8|      SP Narine|
# |IPL-2017|Bangalore|14/04/17|Royal Challengers...|      Mumbai Indians|      Mumbai Indians|        field|normal|         0|      Mumbai Indians|          0|             4|     KA Pollard|
# |IPL-2017|   Rajkot|14/04/17|Rising Pune Super...|       Gujarat Lions|       Gujarat Lions|        field|normal|         0|       Gujarat Lions|          0|             7|         AJ Tye|
# |IPL-2017|  Kolkata|15/04/17|Kolkata Knight Ri...| Sunrisers Hyderabad| Sunrisers Hyderabad|        field|normal|         0|Kolkata Knight Ri...|         17|             0|     RV Uthappa|
# |IPL-2017|    Delhi|15/04/17|    Delhi Daredevils|     Kings XI Punjab|    Delhi Daredevils|          bat|normal|         0|    Delhi Daredevils|         51|             0|    CJ Anderson|
# |IPL-2017|   Mumbai|16/04/17|       Gujarat Lions|      Mumbai Indians|      Mumbai Indians|        field|normal|         0|      Mumbai Indians|          0|             6|         N Rana|
# |IPL-2017|Bangalore|16/04/17|Rising Pune Super...|Royal Challengers...|Royal Challengers...|        field|normal|         0|Rising Pune Super...|         27|             0|      BA Stokes|
# |IPL-2017|    Delhi|17/04/17|    Delhi Daredevils|Kolkata Knight Ri...|    Delhi Daredevils|          bat|normal|         0|Kolkata Knight Ri...|          0|             4|NM Coulter-Nile|
# |IPL-2017|Hyderabad|17/04/17| Sunrisers Hyderabad|     Kings XI Punjab|     Kings XI Punjab|        field|normal|         0| Sunrisers Hyderabad|          5|             0|        B Kumar|
# |IPL-2017|   Rajkot|18/04/17|Royal Challengers...|       Gujarat Lions|       Gujarat Lions|        field|normal|         0|Royal Challengers...|         21|             0|       CH Gayle|
# +--------+---------+--------+--------------------+--------------------+--------------------+-------------+------+----------+--------------------+-----------+--------------+---------------+
# only showing top 20 rows

# %% [markdown]
# ## Data Validation

# %%
matches.describe().show()
# Out:
# +-------+--------+-------------+--------+-------------------+-------------------+-------------------+-------------+---------+--------------------+-------------------+------------------+------------------+---------------+
# |summary|  Season|         city|    date|              team1|              team2|        toss_winner|toss_decision|   result|          dl_applied|             winner|       win_by_runs|    win_by_wickets|player_of_match|
# +-------+--------+-------------+--------+-------------------+-------------------+-------------------+-------------+---------+--------------------+-------------------+------------------+------------------+---------------+
# |  count|     747|          747|     747|                747|                747|                747|          747|      747|                 747|                747|               747|               747|            747|
# |   mean|    null|         null|    null|               null|               null|               null|         null|     null|0.025435073627844713|               null|13.408299866131191| 3.360107095046854|           null|
# | stddev|    null|         null|    null|               null|               null|               null|         null|     null| 0.15754795687209763|               null| 23.57824429303698|3.3913885566833346|           null|
# |    min|IPL-2008|    Abu Dhabi|01/04/10|Chennai Super Kings|Chennai Super Kings|Chennai Super Kings|          bat|no result|                   0|Chennai Super Kings|                 0|                 0|     A Chandila|
# |    max|IPL-2019|Visakhapatnam|31/05/08|Sunrisers Hyderabad|Sunrisers Hyderabad|Sunrisers Hyderabad|        field|      tie|                   1|Sunrisers Hyderabad|                98|                 9|         Z Khan|
# +-------+--------+-------------+--------+-------------------+-------------------+-------------------+-------------+---------+--------------------+-------------------+------------------+------------------+---------------+

# %%
spark.sql('select distinct(team1) from matchesTable').show(truncate = False)
# Out:
# +---------------------------+
# |team1                      |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Rising Pune Supergiant     |
# |Deccan Chargers            |
# |Kochi Tuskers Kerala       |
# |Rajasthan Royals           |
# |Gujarat Lions              |
# |Royal Challengers Bangalore|
# |Kolkata Knight Riders      |
# |Kings XI Punjab            |
# |Pune Warriors              |
# |Delhi Daredevils           |
# |Mumbai Indians             |
# |Rising Pune Supergiants    |
# |Delhi Capitals             |
# +---------------------------+

# %%
spark.sql('select distinct(team2) from matchesTable').show(truncate = False)
# Out:
# +---------------------------+
# |team2                      |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Rising Pune Supergiant     |
# |Deccan Chargers            |
# |Kochi Tuskers Kerala       |
# |Rajasthan Royals           |
# |Gujarat Lions              |
# |Royal Challengers Bangalore|
# |Kolkata Knight Riders      |
# |Kings XI Punjab            |
# |Pune Warriors              |
# |Delhi Daredevils           |
# |Mumbai Indians             |
# |Rising Pune Supergiants    |
# |Delhi Capitals             |
# +---------------------------+

# %%
spark.sql('select distinct(toss_winner) from matchesTable').show(truncate = False)
# Out:
# +---------------------------+
# |toss_winner                |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Rising Pune Supergiant     |
# |Deccan Chargers            |
# |Kochi Tuskers Kerala       |
# |Rajasthan Royals           |
# |Gujarat Lions              |
# |Royal Challengers Bangalore|
# |Kolkata Knight Riders      |
# |Kings XI Punjab            |
# |Pune Warriors              |
# |Delhi Daredevils           |
# |Mumbai Indians             |
# |Rising Pune Supergiants    |
# |Delhi Capitals             |
# +---------------------------+

# %% [markdown]
# There are two records for Pune Team:
#
# 1.   Rising Pune Supergiant
# 2.   Rising Pune Supergiants

# %%
matches = matches.na.replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
matches.select('toss_winner').distinct().show(truncate = False)
# Out:
# +---------------------------+
# |toss_winner                |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Rising Pune Supergiant     |
# |Deccan Chargers            |
# |Kochi Tuskers Kerala       |
# |Rajasthan Royals           |
# |Gujarat Lions              |
# |Royal Challengers Bangalore|
# |Kolkata Knight Riders      |
# |Kings XI Punjab            |
# |Pune Warriors              |
# |Delhi Daredevils           |
# |Mumbai Indians             |
# |Delhi Capitals             |
# +---------------------------+

# %%
matches.select('team1').distinct().show(truncate = False)
# Out:
# +---------------------------+
# |team1                      |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Rising Pune Supergiant     |
# |Deccan Chargers            |
# |Kochi Tuskers Kerala       |
# |Rajasthan Royals           |
# |Gujarat Lions              |
# |Royal Challengers Bangalore|
# |Kolkata Knight Riders      |
# |Kings XI Punjab            |
# |Pune Warriors              |
# |Delhi Daredevils           |
# |Mumbai Indians             |
# |Delhi Capitals             |
# +---------------------------+

# %% [markdown]
# We created only one records for Pune i.e. Rising Pune Supergiant

# %%
#replacing the previous table wit hupdated values in matches
matches.createOrReplaceTempView('matchesTable')

# %%
spark.sql('select distinct(team1) from matchesTable').show(truncate = False)
# Out:
# +---------------------------+
# |team1                      |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Rising Pune Supergiant     |
# |Deccan Chargers            |
# |Kochi Tuskers Kerala       |
# |Rajasthan Royals           |
# |Gujarat Lions              |
# |Royal Challengers Bangalore|
# |Kolkata Knight Riders      |
# |Kings XI Punjab            |
# |Pune Warriors              |
# |Delhi Daredevils           |
# |Mumbai Indians             |
# |Delhi Capitals             |
# +---------------------------+

# %% [markdown]
# ## Data Exploration

# %%
matches.describe().show()
# Out:
# +-------+--------+-------------+--------+-------------------+-------------------+-------------------+-------------+---------+--------------------+-------------------+------------------+------------------+---------------+
# |summary|  Season|         city|    date|              team1|              team2|        toss_winner|toss_decision|   result|          dl_applied|             winner|       win_by_runs|    win_by_wickets|player_of_match|
# +-------+--------+-------------+--------+-------------------+-------------------+-------------------+-------------+---------+--------------------+-------------------+------------------+------------------+---------------+
# |  count|     747|          747|     747|                747|                747|                747|          747|      747|                 747|                747|               747|               747|            747|
# |   mean|    null|         null|    null|               null|               null|               null|         null|     null|0.025435073627844713|               null|13.408299866131191| 3.360107095046854|           null|
# | stddev|    null|         null|    null|               null|               null|               null|         null|     null| 0.15754795687209763|               null| 23.57824429303698|3.3913885566833346|           null|
# |    min|IPL-2008|    Abu Dhabi|01/04/10|Chennai Super Kings|Chennai Super Kings|Chennai Super Kings|          bat|no result|                   0|Chennai Super Kings|                 0|                 0|     A Chandila|
# |    max|IPL-2019|Visakhapatnam|31/05/08|Sunrisers Hyderabad|Sunrisers Hyderabad|Sunrisers Hyderabad|        field|      tie|                   1|Sunrisers Hyderabad|                98|                 9|         Z Khan|
# +-------+--------+-------------+--------+-------------------+-------------------+-------------------+-------------+---------+--------------------+-------------------+------------------+------------------+---------------+

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# 1. Seasons

# %%
spark.sql('select distinct(Season) from matchesTable order by Season').show()
# Out:
# +--------+
# |  Season|
# +--------+
# |IPL-2008|
# |IPL-2009|
# |IPL-2010|
# |IPL-2011|
# |IPL-2012|
# |IPL-2013|
# |IPL-2014|
# |IPL-2015|
# |IPL-2016|
# |IPL-2017|
# |IPL-2018|
# |IPL-2019|
# +--------+

# %% [markdown]
# We have the matches record from 2008 - 2019

# %%
matches.select('Season').distinct().sort('Season').show()
# Out:
# +--------+
# |  Season|
# +--------+
# |IPL-2008|
# |IPL-2009|
# |IPL-2010|
# |IPL-2011|
# |IPL-2012|
# |IPL-2013|
# |IPL-2014|
# |IPL-2015|
# |IPL-2016|
# |IPL-2017|
# |IPL-2018|
# |IPL-2019|
# +--------+

# %%
#Number of matches each season
spark.sql('select Season,count(*) from matchesTable group by Season order by Season').show()
# Out:
# +--------+--------+
# |  Season|count(1)|
# +--------+--------+
# |IPL-2008|      58|
# |IPL-2009|      57|
# |IPL-2010|      60|
# |IPL-2011|      73|
# |IPL-2012|      74|
# |IPL-2013|      76|
# |IPL-2014|      53|
# |IPL-2015|      58|
# |IPL-2016|      60|
# |IPL-2017|      59|
# |IPL-2018|      60|
# |IPL-2019|      59|
# +--------+--------+

# %% [markdown]
# Season 2011 - 2013 seems to have a bit high number of matches. We'll Explore on this part

# %%
matches.groupBy('Season').agg(count('Season').alias('Count')).sort('Season').show()
# Out:
# +--------+-----+
# |  Season|Count|
# +--------+-----+
# |IPL-2008|   58|
# |IPL-2009|   57|
# |IPL-2010|   60|
# |IPL-2011|   73|
# |IPL-2012|   74|
# |IPL-2013|   76|
# |IPL-2014|   53|
# |IPL-2015|   58|
# |IPL-2016|   60|
# |IPL-2017|   59|
# |IPL-2018|   60|
# |IPL-2019|   59|
# +--------+-----+

# %% [markdown]
# 2. City

# %%
spark.sql('select distinct(city) from matchesTable').show()
# Out:
# +------------+
# |        city|
# +------------+
# |   Bangalore|
# |       Kochi|
# |     Chennai|
# |   Centurion|
# |      Mumbai|
# |   Ahmedabad|
# |      Durban|
# |     Kolkata|
# |   Cape Town|
# |  Dharamsala|
# |        Pune|
# |Johannesburg|
# |   Kimberley|
# |       Delhi|
# |  Chandigarh|
# |      Nagpur|
# |Bloemfontein|
# |      Kanpur|
# |   Hyderabad|
# |      Rajkot|
# +------------+
# only showing top 20 rows

# %%
spark.sql('select count(distinct(city)) from matchesTable').show()
# Out:
# +--------------------+
# |count(DISTINCT city)|
# +--------------------+
# |                  32|
# +--------------------+

# %% [markdown]
# There are 32 cities in total where the matches were being played from 2008 - 2019

# %%
matches.select('city').distinct().show()
# Out:
# +------------+
# |        city|
# +------------+
# |   Bangalore|
# |       Kochi|
# |     Chennai|
# |   Centurion|
# |      Mumbai|
# |   Ahmedabad|
# |      Durban|
# |     Kolkata|
# |   Cape Town|
# |  Dharamsala|
# |        Pune|
# |Johannesburg|
# |   Kimberley|
# |       Delhi|
# |  Chandigarh|
# |      Nagpur|
# |Bloemfontein|
# |      Kanpur|
# |   Hyderabad|
# |      Rajkot|
# +------------+
# only showing top 20 rows

# %%
matches.select('city').distinct().count()
# Out:
# 32

# %%
#Count of matches in each city
spark.sql('select city,count(*) as Counts from matchesTable group by city order by Counts desc').show(32)
# Out:
# +--------------+------+
# |          city|Counts|
# +--------------+------+
# |        Mumbai|   101|
# |       Kolkata|    77|
# |         Delhi|    74|
# |     Bangalore|    65|
# |     Hyderabad|    64|
# |       Chennai|    57|
# |        Jaipur|    47|
# |    Chandigarh|    46|
# |          Pune|    38|
# |        Durban|    15|
# |     Bengaluru|    13|
# | Visakhapatnam|    13|
# |     Centurion|    12|
# |     Ahmedabad|    12|
# |        Rajkot|    10|
# |        Mohali|    10|
# |        Indore|     9|
# |    Dharamsala|     9|
# |  Johannesburg|     8|
# |Port Elizabeth|     7|
# |       Cuttack|     7|
# |        Ranchi|     7|
# |     Cape Town|     7|
# |     Abu Dhabi|     7|
# |        Raipur|     6|
# |       Sharjah|     6|
# |         Kochi|     5|
# |        Kanpur|     4|
# |     Kimberley|     3|
# |        Nagpur|     3|
# |   East London|     3|
# |  Bloemfontein|     2|
# +--------------+------+

# %% [markdown]
# Mumbai has hosted the highest number of matches

# %%
matches.groupBy('city').agg(count('city').alias('Counts')).orderBy(desc('Counts')).show(32)
# Out:
# +--------------+------+
# |          city|Counts|
# +--------------+------+
# |        Mumbai|   101|
# |       Kolkata|    77|
# |         Delhi|    74|
# |     Bangalore|    65|
# |     Hyderabad|    64|
# |       Chennai|    57|
# |        Jaipur|    47|
# |    Chandigarh|    46|
# |          Pune|    38|
# |        Durban|    15|
# |     Bengaluru|    13|
# | Visakhapatnam|    13|
# |     Centurion|    12|
# |     Ahmedabad|    12|
# |        Rajkot|    10|
# |        Mohali|    10|
# |        Indore|     9|
# |    Dharamsala|     9|
# |  Johannesburg|     8|
# |Port Elizabeth|     7|
# |       Cuttack|     7|
# |        Ranchi|     7|
# |     Cape Town|     7|
# |     Abu Dhabi|     7|
# |        Raipur|     6|
# |       Sharjah|     6|
# |         Kochi|     5|
# |        Kanpur|     4|
# |     Kimberley|     3|
# |        Nagpur|     3|
# |   East London|     3|
# |  Bloemfontein|     2|
# +--------------+------+

# %% [markdown]
# 3.Toss Winner

# %%
spark.sql('select distinct(toss_winner) from matchesTable').show(truncate = False)
# Out:
# +---------------------------+
# |toss_winner                |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Rising Pune Supergiant     |
# |Deccan Chargers            |
# |Kochi Tuskers Kerala       |
# |Rajasthan Royals           |
# |Gujarat Lions              |
# |Royal Challengers Bangalore|
# |Kolkata Knight Riders      |
# |Kings XI Punjab            |
# |Pune Warriors              |
# |Delhi Daredevils           |
# |Mumbai Indians             |
# |Delhi Capitals             |
# +---------------------------+

# %% [markdown]
# These are basically all the teams which participated iin IPL upto 2019

# %%
matches.select('toss_winner').distinct().show(truncate = False)
# Out:
# +---------------------------+
# |toss_winner                |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Rising Pune Supergiant     |
# |Deccan Chargers            |
# |Kochi Tuskers Kerala       |
# |Rajasthan Royals           |
# |Gujarat Lions              |
# |Royal Challengers Bangalore|
# |Kolkata Knight Riders      |
# |Kings XI Punjab            |
# |Pune Warriors              |
# |Delhi Daredevils           |
# |Mumbai Indians             |
# |Delhi Capitals             |
# +---------------------------+

# %%
spark.sql('select toss_winner,count(*) as Counts from matchesTable group by toss_winner \
order by Counts desc').show(truncate = False)
# Out:
# +---------------------------+------+
# |toss_winner                |Counts|
# +---------------------------+------+
# |Mumbai Indians             |96    |
# |Kolkata Knight Riders      |91    |
# |Chennai Super Kings        |89    |
# |Kings XI Punjab            |80    |
# |Royal Challengers Bangalore|80    |
# |Delhi Daredevils           |80    |
# |Rajasthan Royals           |77    |
# |Sunrisers Hyderabad        |45    |
# |Deccan Chargers            |43    |
# |Pune Warriors              |20    |
# |Gujarat Lions              |15    |
# |Rising Pune Supergiant     |13    |
# |Delhi Capitals             |10    |
# |Kochi Tuskers Kerala       |8     |
# +---------------------------+------+

# %% [markdown]
# Mumbai Indians have won the highest toss counts

# %%
matches.groupBy('toss_winner').agg(count('toss_winner').alias('counts_toss_won'))\
.orderBy(desc('counts_toss_won')).show(truncate = False)
# Out:
# +---------------------------+---------------+
# |toss_winner                |counts_toss_won|
# +---------------------------+---------------+
# |Mumbai Indians             |96             |
# |Kolkata Knight Riders      |91             |
# |Chennai Super Kings        |89             |
# |Kings XI Punjab            |80             |
# |Royal Challengers Bangalore|80             |
# |Delhi Daredevils           |80             |
# |Rajasthan Royals           |77             |
# |Sunrisers Hyderabad        |45             |
# |Deccan Chargers            |43             |
# |Pune Warriors              |20             |
# |Gujarat Lions              |15             |
# |Rising Pune Supergiant     |13             |
# |Delhi Capitals             |10             |
# |Kochi Tuskers Kerala       |8              |
# +---------------------------+---------------+

# %% [markdown]
# 3. Toss Decision

# %%
spark.sql('select toss_decision,count(*) as Count from matchesTable group by toss_decision').show()
# Out:
# +-------------+-----+
# |toss_decision|Count|
# +-------------+-----+
# |        field|  457|
# |          bat|  290|
# +-------------+-----+

# %%
from ast import expr
matches.groupBy('toss_decision').agg(count('toss_decision'),(count('toss_decision')/matches.count()).\
                                     alias('percent')).show()
# Out:
# +-------------+--------------------+-------------------+
# |toss_decision|count(toss_decision)|            percent|
# +-------------+--------------------+-------------------+
# |        field|                 457| 0.6117804551539491|
# |          bat|                 290|0.38821954484605087|
# +-------------+--------------------+-------------------+

# %% [markdown]
# After winning the toss 61% of times the team choose to field first

# %% [markdown]
# 4. Result

# %%
spark.sql('select result,count(*) as counts from matchesTable group by result').show()
# Out:
# +---------+------+
# |   result|counts|
# +---------+------+
# |   normal|   736|
# |      tie|     9|
# |no result|     2|
# +---------+------+

# %%
matches.groupBy('result').agg(count('result').alias('counts')).show()
# Out:
# +---------+------+
# |   result|counts|
# +---------+------+
# |   normal|   736|
# |      tie|     9|
# |no result|     2|
# +---------+------+

# %% [markdown]
# 5. DL applied

# %%
spark.sql('select dl_applied,count(*),count(*)/747 as percent from matchesTable group by dl_applied').show(3)
# Out:
# +----------+--------+--------------------+
# |dl_applied|count(1)|             percent|
# +----------+--------+--------------------+
# |         0|     728|  0.9745649263721553|
# |         1|      19|0.025435073627844713|
# +----------+--------+--------------------+

# %% [markdown]
# Duck Worth luis was used in 19 games total

# %%
matches.groupBy('dl_applied').agg(count('dl_applied'), (count('dl_applied')/matches.count())\
                                  .alias('percent')).show()
# Out:
# +----------+-----------------+--------------------+
# |dl_applied|count(dl_applied)|             percent|
# +----------+-----------------+--------------------+
# |         0|              728|  0.9745649263721553|
# |         1|               19|0.025435073627844713|
# +----------+-----------------+--------------------+

# %% [markdown]
# 6. Winner

# %%
spark.sql('select winner,count(*) as counts from matchesTable group by winner order by counts desc')\
.show(truncate = False)
# Out:
# +---------------------------+------+
# |winner                     |counts|
# +---------------------------+------+
# |Mumbai Indians             |109   |
# |Chennai Super Kings        |98    |
# |Kolkata Knight Riders      |92    |
# |Royal Challengers Bangalore|83    |
# |Kings XI Punjab            |81    |
# |Rajasthan Royals           |75    |
# |Delhi Daredevils           |66    |
# |Sunrisers Hyderabad        |56    |
# |Deccan Chargers            |29    |
# |Rising Pune Supergiant     |15    |
# |Gujarat Lions              |13    |
# |Pune Warriors              |12    |
# |Delhi Capitals             |10    |
# |Kochi Tuskers Kerala       |6     |
# |N.A                        |2     |
# +---------------------------+------+

# %%
matches.groupBy('winner').agg(count('winner').alias('matches_won')).orderBy(desc('matches_won'))\
.show(truncate = False)
# Out:
# +---------------------------+-----------+
# |winner                     |matches_won|
# +---------------------------+-----------+
# |Mumbai Indians             |109        |
# |Chennai Super Kings        |98         |
# |Kolkata Knight Riders      |92         |
# |Royal Challengers Bangalore|83         |
# |Kings XI Punjab            |81         |
# |Rajasthan Royals           |75         |
# |Delhi Daredevils           |66         |
# |Sunrisers Hyderabad        |56         |
# |Deccan Chargers            |29         |
# |Rising Pune Supergiant     |15         |
# |Gujarat Lions              |13         |
# |Pune Warriors              |12         |
# |Delhi Capitals             |10         |
# |Kochi Tuskers Kerala       |6          |
# |N.A                        |2          |
# +---------------------------+-----------+

# %% [markdown]
# Mumbai Indians have won the maximum number of matches followd by Chennai Super Kings

# %% [markdown]
# N.A are the matches which were having no results

# %% [markdown]
# 7. Win By Runs

# %%
spark.sql('select max(win_by_runs) from matchesTable').show()
# Out:
# +----------------+
# |max(win_by_runs)|
# +----------------+
# |              98|
# +----------------+

# %%
matches.select(max('win_by_runs')).show()
# Out:
# +----------------+
# |max(win_by_runs)|
# +----------------+
# |              98|
# +----------------+

# %% [markdown]
# 8. Win By Wickets

# %%
spark.sql('select max(win_by_wickets) from matchesTable').show()
# Out:
# +-------------------+
# |max(win_by_wickets)|
# +-------------------+
# |                  9|
# +-------------------+

# %% [markdown]
# There is no win by 10 wickets

# %%
matches.select(max('win_by_wickets')).show()
# Out:
# +-------------------+
# |max(win_by_wickets)|
# +-------------------+
# |                  9|
# +-------------------+

# %%
spark.sql('select player_of_match, count(*) as counts from matchesTable group by player_of_match order by counts desc').show(truncate = False)
# Out:
# +---------------+------+
# |player_of_match|counts|
# +---------------+------+
# |CH Gayle       |21    |
# |AB de Villiers |20    |
# |RG Sharma      |17    |
# |DA Warner      |17    |
# |MS Dhoni       |17    |
# |YK Pathan      |16    |
# |SR Watson      |15    |
# |SK Raina       |14    |
# |G Gambhir      |13    |
# |MEK Hussey     |12    |
# |V Kohli        |12    |
# |AM Rahane      |12    |
# |V Sehwag       |11    |
# |A Mishra       |11    |
# |DR Smith       |11    |
# |AD Russell     |11    |
# |KA Pollard     |10    |
# |JH Kallis      |10    |
# |SP Narine      |9     |
# |SE Marsh       |9     |
# +---------------+------+
# only showing top 20 rows

# %%
matches.groupBy('player_of_match').agg((count('player_of_match')).alias('POM_count')).orderBy(desc('POM_count')).show()
# Out:
# +---------------+---------+
# |player_of_match|POM_count|
# +---------------+---------+
# |       CH Gayle|       21|
# | AB de Villiers|       20|
# |      RG Sharma|       17|
# |      DA Warner|       17|
# |       MS Dhoni|       17|
# |      YK Pathan|       16|
# |      SR Watson|       15|
# |       SK Raina|       14|
# |      G Gambhir|       13|
# |     MEK Hussey|       12|
# |        V Kohli|       12|
# |      AM Rahane|       12|
# |       V Sehwag|       11|
# |       A Mishra|       11|
# |       DR Smith|       11|
# |     AD Russell|       11|
# |     KA Pollard|       10|
# |      JH Kallis|       10|
# |      SP Narine|        9|
# |       SE Marsh|        9|
# +---------------+---------+
# only showing top 20 rows

# %% [markdown]
# ### Multivariate Analysis

# %%
spark.sql('select count(*), count(*)/747 as percent from matchesTable where toss_winner = winner').show()
# Out:
# +--------+------------------+
# |count(1)|           percent|
# +--------+------------------+
# |     390|0.5220883534136547|
# +--------+------------------+

# %% [markdown]
# The teams which have won the toss have won the matches about 50% of times

# %% [markdown]
# This means that winning the toss has no significant impact on the outcome of the match

# %%
field_df = spark.sql('select * from matchesTable where toss_decision = "field"')

# %%
field_df.groupBy('city').agg(count('city').alias('counts')).orderBy(desc('counts')).show(32)
# Out:
# +-------------+------+
# |         city|counts|
# +-------------+------+
# |       Mumbai|    66|
# |    Bangalore|    56|
# |      Kolkata|    49|
# |        Delhi|    42|
# |    Hyderabad|    36|
# |   Chandigarh|    30|
# |       Jaipur|    28|
# |      Chennai|    21|
# |         Pune|    21|
# |    Bengaluru|    13|
# |       Mohali|     9|
# |   Dharamsala|     8|
# |       Indore|     8|
# |Visakhapatnam|     8|
# |       Rajkot|     7|
# |    Ahmedabad|     6|
# | Johannesburg|     6|
# |    Centurion|     6|
# |       Durban|     5|
# |      Cuttack|     5|
# |       Ranchi|     4|
# |      Sharjah|     4|
# |       Kanpur|     4|
# |       Raipur|     3|
# |    Abu Dhabi|     3|
# |    Cape Town|     3|
# |        Kochi|     3|
# |    Kimberley|     1|
# |       Nagpur|     1|
# | Bloemfontein|     1|
# +-------------+------+

# %%
bat_df = spark.sql('select * from matchesTable where toss_decision = "bat"')

# %%
bat_df.groupBy('city').agg(count('city').alias('counts')).orderBy(desc('counts')).show(32)
# Out:
# +--------------+------+
# |          city|counts|
# +--------------+------+
# |       Chennai|    36|
# |        Mumbai|    35|
# |         Delhi|    32|
# |     Hyderabad|    28|
# |       Kolkata|    28|
# |        Jaipur|    19|
# |          Pune|    17|
# |    Chandigarh|    16|
# |        Durban|    10|
# |     Bangalore|     9|
# |Port Elizabeth|     7|
# |     Centurion|     6|
# |     Ahmedabad|     6|
# | Visakhapatnam|     5|
# |     Cape Town|     4|
# |     Abu Dhabi|     4|
# |        Ranchi|     3|
# |        Raipur|     3|
# |        Rajkot|     3|
# |   East London|     3|
# |  Johannesburg|     2|
# |     Kimberley|     2|
# |        Nagpur|     2|
# |       Cuttack|     2|
# |         Kochi|     2|
# |       Sharjah|     2|
# |    Dharamsala|     1|
# |  Bloemfontein|     1|
# |        Indore|     1|
# |        Mohali|     1|
# +--------------+------+

# %% [markdown]
# We can see the toss preferances as per each city stadiums

# %% [markdown]
# Some cities are preferred for fielding first while some for batting

# %%
team1 = matches.select('team1')

# %%
team2 = matches.select('team2')

# %%
teams = team1.union(team2)

# %%
teams.count()
# Out:
# 1494

# %%
teams.show(truncate = False)
# Out:
# +---------------------------+
# |team1                      |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Mumbai Indians             |
# |Gujarat Lions              |
# |Rising Pune Supergiant     |
# |Royal Challengers Bangalore|
# |Gujarat Lions              |
# |Kolkata Knight Riders      |
# |Royal Challengers Bangalore|
# |Delhi Daredevils           |
# |Sunrisers Hyderabad        |
# |Kings XI Punjab            |
# |Royal Challengers Bangalore|
# |Rising Pune Supergiant     |
# |Kolkata Knight Riders      |
# |Delhi Daredevils           |
# |Gujarat Lions              |
# |Rising Pune Supergiant     |
# |Delhi Daredevils           |
# |Sunrisers Hyderabad        |
# |Royal Challengers Bangalore|
# +---------------------------+
# only showing top 20 rows

# %%
teams = teams.withColumnRenamed('team1','teams')

# %%
teams.show(truncate = False)
# Out:
# +---------------------------+
# |teams                      |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Mumbai Indians             |
# |Gujarat Lions              |
# |Rising Pune Supergiant     |
# |Royal Challengers Bangalore|
# |Gujarat Lions              |
# |Kolkata Knight Riders      |
# |Royal Challengers Bangalore|
# |Delhi Daredevils           |
# |Sunrisers Hyderabad        |
# |Kings XI Punjab            |
# |Royal Challengers Bangalore|
# |Rising Pune Supergiant     |
# |Kolkata Knight Riders      |
# |Delhi Daredevils           |
# |Gujarat Lions              |
# |Rising Pune Supergiant     |
# |Delhi Daredevils           |
# |Sunrisers Hyderabad        |
# |Royal Challengers Bangalore|
# +---------------------------+
# only showing top 20 rows

# %%
teams.groupBy('teams').agg(count('teams').alias('Matches_played')).orderBy(desc('Matches_played'))\
.show(truncate = False)
# Out:
# +---------------------------+--------------+
# |teams                      |Matches_played|
# +---------------------------+--------------+
# |Mumbai Indians             |184           |
# |Kolkata Knight Riders      |177           |
# |Royal Challengers Bangalore|176           |
# |Kings XI Punjab            |175           |
# |Chennai Super Kings        |162           |
# |Delhi Daredevils           |159           |
# |Rajasthan Royals           |144           |
# |Sunrisers Hyderabad        |106           |
# |Deccan Chargers            |75            |
# |Pune Warriors              |46            |
# |Gujarat Lions              |30            |
# |Rising Pune Supergiant     |30            |
# |Delhi Capitals             |16            |
# |Kochi Tuskers Kerala       |14            |
# +---------------------------+--------------+

# %% [markdown]
# Mumbai Indians have played the highest number of matches.

# %%
team_matches = teams.groupBy('teams').agg(count('teams').alias('Matches_played')).\
orderBy(desc('Matches_played'))
toss = matches.groupBy('toss_winner').agg(count('toss_winner').alias('toss_wins'))

# %%
team_toss = team_matches.join(toss, toss['toss_winner'] == team_matches['teams'], 'inner')
team_toss = team_toss.drop('toss_winner')

# %%
team_toss = team_toss.withColumn('percent', team_toss.toss_wins / team_toss.Matches_played).\
orderBy(desc('percent'))

# %%
team_toss.show(truncate = False)
# Out:
# +---------------------------+--------------+---------+-------------------+
# |teams                      |Matches_played|toss_wins|percent            |
# +---------------------------+--------------+---------+-------------------+
# |Delhi Capitals             |16            |10       |0.625              |
# |Deccan Chargers            |75            |43       |0.5733333333333334 |
# |Kochi Tuskers Kerala       |14            |8        |0.5714285714285714 |
# |Chennai Super Kings        |162           |89       |0.5493827160493827 |
# |Rajasthan Royals           |144           |77       |0.5347222222222222 |
# |Mumbai Indians             |184           |96       |0.5217391304347826 |
# |Kolkata Knight Riders      |177           |91       |0.5141242937853108 |
# |Delhi Daredevils           |159           |80       |0.5031446540880503 |
# |Gujarat Lions              |30            |15       |0.5                |
# |Kings XI Punjab            |175           |80       |0.45714285714285713|
# |Royal Challengers Bangalore|176           |80       |0.45454545454545453|
# |Pune Warriors              |46            |20       |0.43478260869565216|
# |Rising Pune Supergiant     |30            |13       |0.43333333333333335|
# |Sunrisers Hyderabad        |106           |45       |0.42452830188679247|
# +---------------------------+--------------+---------+-------------------+

# %% [markdown]
# Delhi Capitals have a slightly higher percentage of toss wins.

# %%
winner = matches.groupBy('winner').agg(count('winner').alias('wins')).orderBy(desc('wins'))

# %%
team_wins = team_matches.join(winner, team_matches['teams'] == winner['winner'], 'inner')
team_wins = team_wins.drop('winner')

# %%
team_wins = team_wins.withColumn('percent', team_wins.wins / team_wins.Matches_played)\
.orderBy(desc('percent'))

# %%
team_wins.show(truncate = False)
# Out:
# +---------------------------+--------------+----+-------------------+
# |teams                      |Matches_played|wins|percent            |
# +---------------------------+--------------+----+-------------------+
# |Delhi Capitals             |16            |10  |0.625              |
# |Chennai Super Kings        |162           |98  |0.6049382716049383 |
# |Mumbai Indians             |184           |109 |0.592391304347826  |
# |Sunrisers Hyderabad        |106           |56  |0.5283018867924528 |
# |Rajasthan Royals           |144           |75  |0.5208333333333334 |
# |Kolkata Knight Riders      |177           |92  |0.519774011299435  |
# |Rising Pune Supergiant     |30            |15  |0.5                |
# |Royal Challengers Bangalore|176           |83  |0.4715909090909091 |
# |Kings XI Punjab            |175           |81  |0.46285714285714286|
# |Gujarat Lions              |30            |13  |0.43333333333333335|
# |Kochi Tuskers Kerala       |14            |6   |0.42857142857142855|
# |Delhi Daredevils           |159           |66  |0.41509433962264153|
# |Deccan Chargers            |75            |29  |0.38666666666666666|
# |Pune Warriors              |46            |12  |0.2608695652173913 |
# +---------------------------+--------------+----+-------------------+

# %% [markdown]
# 1.   Delhi Capitals have the highest win percentages. But they have played less number of matches as compared to others
# 2.   Though Mumbai Indians have highest match win counts but their win percentage is lower and ranked at third.
# 3.   Delhi Daredevils and Deccan Chargers had low win percentages. But it changed with changes made to the team. Its visible from the win percenatges of Delhi Capitals and Sunrisers Hyderabad respectively.
